# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
wine = pd.read_csv('session11.csv')

# %%
wine
# Out:
#         Unnamed: 0      country  \
# 0                0           US
# 1                1        Spain
# 2                2           US
# 3                3           US
# 4                4       France
# 5                5        Spain
# 6                6        Spain
# 7                7        Spain
# 8                8           US
# 9                9           US
# 10              10        Italy
# 11              11           US
# 12              12           US
# 13              13       France
# 14              14           US
# 15              15           US
# 16              16           US
# 17              17        Spain
# 18              18       France
# 19              19           US
# 20              20           US
# 21              21        Spain
# 22              22        Spain
# 23              23           US
# 24              24           US
# 25              25  New Zealand
# 26              26           US
# 27              27           US
# ...

# %%
price = wine[['price']]

# %%
price.mean(axis=0)
# Out:
# price    33.131482
# dtype: float64

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150930 entries, 0 to 150929
# Data columns (total 11 columns):
# Unnamed: 0     150930 non-null int64
# country        150925 non-null object
# description    150930 non-null object
# designation    105195 non-null object
# points         150930 non-null int64
# price          137235 non-null float64
# province       150925 non-null object
# region_1       125870 non-null object
# region_2       60953 non-null object
# variety        150930 non-null object
# winery         150930 non-null object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 12.7+ MB

# %%
plt.hist(price.values,50,(0,250))
# Out:
# /Users/vince/anaconda3/envs/ml/lib/python3.7/site-packages/numpy/lib/histograms.py:754: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/vince/anaconda3/envs/ml/lib/python3.7/site-packages/numpy/lib/histograms.py:755: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# (array([1.8000e+01, 5.1420e+03, 2.1677e+04, 2.4118e+04, 1.8265e+04,
#         1.3881e+04, 9.8470e+03, 8.9520e+03, 6.6300e+03, 5.8730e+03,
#         4.6190e+03, 2.9260e+03, 2.7340e+03, 1.9960e+03, 1.4160e+03,
#         1.8180e+03, 9.9800e+02, 8.3700e+02, 8.1200e+02, 5.4300e+02,
#         7.4100e+02, 1.9300e+02, 2.8100e+02, 1.4300e+02, 3.0500e+02,
#         3.8600e+02, 1.3800e+02, 1.4500e+02, 1.3500e+02, 8.9000e+01,
#         2.5700e+02, 5.5000e+01, 4.8000e+01, 6.0000e+01, 3.8000e+01,
#         9.5000e+01, 5.7000e+01, 2.4000e+01, 3.0000e+01, 4.6000e+01,
#         1.0400e+02, 1.8000e+01, 3.3000e+01, 1.7000e+01, 2.0000e+01,
# ...

# %%
wine = wine[['country','points','price','province','variety']]

# %%
wine.describe()
# Out:
#               points          price
# count  150930.000000  137235.000000
# mean       87.888418      33.131482
# std         3.222392      36.322536
# min        80.000000       4.000000
# 25%        86.000000      16.000000
# 50%        88.000000      24.000000
# 75%        90.000000      40.000000
# max       100.000000    2300.000000

# %%
wine2 = wine.dropna() # drop all of the empty

# %%
wine2.describe()
# Out:
#               points          price
# count  137230.000000  137230.000000
# mean       87.788035      33.132019
# std         3.221572      36.323072
# min        80.000000       4.000000
# 25%        86.000000      16.000000
# 50%        88.000000      24.000000
# 75%        90.000000      40.000000
# max       100.000000    2300.000000

# %%
scores = wine2['points']

# %%
sumScores = sum(scores)

numScores = len(scores)

avgScores = sumScores/numScores
avgScores
# Out:
# 87.78803468629309

# %%
plt.scatter(scores, wine2['price'])

# %%
np.mean(scores)
# Out:
# 87.78803468629309

# %%
prices = wine2['price']

# %%
np.mean(prices)
# Out:
# 33.132019237776

# %%
np.median(prices)
# Out:
# 24.0

# %%
sortedPrices = sorted(prices)

# %%
middle1 = len(prices)/2
middle2 = middle1 -1

# %%
prices.mode() # this is the price that is the most common in the dataset
# Out:
# 0    20.0
# dtype: float64

# %%
prices.value_counts() # this is a frequenct table
# Out:
# 20.0      7860
# 15.0      7053
# 18.0      5988
# 25.0      5955
# 30.0      5448
# 10.0      5255
# 12.0      4950
# 13.0      4479
# 16.0      4273
# 35.0      4194
# 40.0      4018
# 14.0      3879
# 22.0      3723
# 17.0      3512
# 24.0      3443
# 50.0      3415
# 28.0      3352
# 19.0      3288
# 45.0      3243
# 11.0      3114
# 9.0       2350
# 32.0      2197
# 60.0      2179
# 23.0      1785
# 55.0      1785
# 38.0      1780
# 26.0      1766
# 8.0       1633
# 75.0      1510
# 36.0      1480
#           ...
# 530.0        1
# 848.0        1
# 1300.0       1
# 574.0        1
# 455.0        1
# 178.0        1
# 426.0        1
# 612.0        1
# 900.0        1
# 196.0        1
# 685.0        1
# 1900.0       1
# 226.0        1
# 428.0        1
# 282.0        1
# 151.0        1
# 2300.0       1
# 172.0        1
# 268.0        1
# 510.0        1
# 415.0        1
# 271.0        1
# 335.0        1
# 398.0        1
# 319.0        1
# 740.0        1
# 545.0        1
# ...

# %%
prices.value_counts()/len(prices)*100
# Out:
# 20.0      5.727611
# 15.0      5.139547
# 18.0      4.363477
# 25.0      4.339430
# 30.0      3.969977
# 10.0      3.829338
# 12.0      3.607083
# 13.0      3.263864
# 16.0      3.113751
# 35.0      3.056183
# 40.0      2.927931
# 14.0      2.826641
# 22.0      2.712964
# 17.0      2.559207
# 24.0      2.508927
# 50.0      2.488523
# 28.0      2.442615
# 19.0      2.395978
# 45.0      2.363186
# 11.0      2.269183
# 9.0       1.712454
# 32.0      1.600962
# 60.0      1.587845
# 23.0      1.300736
# 55.0      1.300736
# 38.0      1.297092
# 26.0      1.286891
# 8.0       1.189973
# 75.0      1.100342
# 36.0      1.078481
#             ...
# 530.0     0.000729
# 848.0     0.000729
# 1300.0    0.000729
# 574.0     0.000729
# 455.0     0.000729
# 178.0     0.000729
# 426.0     0.000729
# 612.0     0.000729
# 900.0     0.000729
# 196.0     0.000729
# 685.0     0.000729
# 1900.0    0.000729
# 226.0     0.000729
# 428.0     0.000729
# 282.0     0.000729
# 151.0     0.000729
# ...

# %%
def stdevv(nums):
    diffs = 0
    avg = sum(nums)/len(nums)
    for n in nums:
        diffs = diffs + (n - avg)**2
    return (diffs/(len(nums)))**0.5

# %%
stdevv(prices)
# Out:
# 36.32293953967518

# %%
np.std(prices)
# Out:
# 36.32293953967593

# %%
prices2 = wine2['price']

# %%
prices_less100 = prices2[prices2 < 100]

# %%
plt.boxplot(prices_less100)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x117509e80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1174a7e10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1174a7390>],
#  'medians': [<matplotlib.lines.Line2D at 0x1174b04e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1174b0828>],
#  'means': []}

# %%
prices_less100.hist()
